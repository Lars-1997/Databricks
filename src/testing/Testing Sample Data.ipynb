# %% [markdown]
# ## Load Data From CSV
# ### Import Packages

# %%
import pyspark.sql.functions as F
from pyspark.sql.window import Window
from pyspark.sql.types import (
    StructType,
    StructField,
    IntegerType,
    StringType,
)

# %% [markdown]
# ### Set Variables

# %% [markdown]
# ### Create Schema

# %%
schema = StructType(
    [
        StructField(
            name="Year",
            dataType=IntegerType(),
            nullable=False,
            metadata={"comment": "Description of the year the entry was made"}
        ),
        StructField(
            name="Industry_aggregation_NZSIOC",
            dataType=StringType(),
            nullable=False,
            metadata={"comment": "Description of the aggregation of the row as of NZSIOC"}
        ),
        StructField(
            name="Industry_code_NZSIOC",
            dataType=StringType(),
            nullable=False,
            metadata={"comment": "Description of the code of the row as of NZSIOC"}
        ),
        StructField(
            name="Industry_name_NZSIOC",
            dataType=StringType(),
            nullable=False,
            metadata={"comment": "Description of the name of the row as of NZSIOC"}
        ),
        StructField(
            name="Units",
            dataType=StringType(),
            nullable=False,
            metadata={"comment": "Description of the unit as currency(Aggregation)"}
        ),
        StructField(
            name="Variable_code",
            dataType=StringType(),
            nullable=False,
            metadata={"comment": "Description of the year the entry was made"}
        ),
        StructField(
            name="Variable_name",
            dataType=StringType(),
            nullable=False,
            metadata={"comment": "Description of the year the entry was made"}
        ),
        StructField(
            name="Variable_category",
            dataType=StringType(),
            nullable=False,
            metadata={"comment": "Description of the year the entry was made"}
        ),
        StructField(
            name="Value",
            dataType=StringType(),
            nullable=False,
            metadata={"comment": "Description of the year the entry was made"}
        ),
        StructField(
            name="Industry_code_ANZSIC06",
            dataType=StringType(),
            nullable=False,
            metadata={"comment": "Description of the year the entry was made"}
        ),
    ]
)

# %% [markdown]
# ### ETL

# %%
df = spark.read.option("header", True).csv(path="/Volumes/workspace/test_sql_commands/csv/annual-enterprise-survey-2024-financial-year-provisional.csv")
display(df)

# %%
df_forcast = spark.read.table("samples.accuweather.forecast_daily_calendar_imperial")
#df_forcast = df_forcast.filter(F.col("city_name") == "NewYork")
display(df_forcast)

# %%
df_nyctaxi_yellow = spark.read.format("delta").load("/databricks-datasets/nyctaxi/tables/nyctaxi_yellow")
display(df_nyctaxi_yellow)
